# %%
import osmnx as ox
import geopandas as gpd
import matplotlib.pyplot as plt

location = gpd.read_file('map_src/export.geojson')
buldings = location
location.plot(color = "gray")
# Out:
# <Axes: >

# %%
location
# Out:
#                id             @id   alt_name    building heritage  \
# 0    way/30285309    way/30285309        NaN  university      yes
# 1    way/37048692    way/37048692        NaN  university      yes
# 2    way/37928720    way/37928720  Elektro G  university      yes
# 3  way/1039395938  way/1039395938        NaN  university      NaN
# 4  way/1039396093  way/1039396093        NaN   warehouse      NaN
#
#                    name                              name:en ntnu:building  \
# 0  NTNU. Hovedbygningen   NTNU. Main Administration Building           yes
# 1      Østre Gløshaugen                   Eastern Gløshaugen           yes
# 2         Gamle elektro  Old Electrical Engineering Building           yes
# 3                   NaN                                  NaN           NaN
# 4                   NaN                                  NaN           NaN
#
#   ntnu:buildingid                                        operator  \
# ...

# %%
#location['geometry'][4]
location.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
tags = {"building" : True}
buildings_final = ox.geometries.geometries_from_polygon(location['geometry'][0], tags)
#buildings_final = gpd.clip(buildings_final, location)
# Out:
# c:\Users\karlg\AppData\Local\Programs\Python\Python310\lib\site-packages\geopandas\tools\clip.py:67: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   clipped.loc[

# %%
buildings_final.plot()
# Out:
# <Axes: >
